# %%
#!/usr/bin/env python
# coding: utf-8

import os
import pickle
import pandas as pd
import numpy as np
import win32timezone
import datetime as dt
from datetime import datetime
print('-'*300)
print("Welcome to the quant Email Scraper.\nDeveloped by quants seniormost/juniormost Python developer.\nA summary of all company reasearch reports from CITI, Jefferies and Macquarie will appear in the same folder as this file titled as ReportSummary <Date_time>.\nTo continue please enter the following details\n\n ")
year=int(input('Enter the year you want the reports from yy eg 24'))
month = int(input('Enter a month as integer 01-12 : '))
day = int(input('Enter a day as integer 01-31 dd: '))
hours =int(float(input('Enter the time in format hhmm eg 1750 for 5:50 p.m. : ')))
minutes=hours%100
hours=int(hours/100)
print(hours,minutes)
try:
	todays_date= datetime(year+2000, month, day, hours, minutes, 0)#+timedelta(hours=5.5)
except:
    print("error in format")
    buffer=input("press any key to exit")
    quit()

print(f"Now showing from :{todays_date} to present")
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Welcome to the quant Email Scraper.
# Developed by quants seniormost/juniormost Python developer.
# A summary of all company reasearch reports from CITI, Jefferies and Macquarie will appear in the same folder as this file titled as ReportSummary <Date_time>.
# To continue please enter the following details
# Enter the year you want the reports from yy eg 24 24
# Enter a month as integer 01-12 :  6
# Enter a day as integer 01-31 dd:  25
# Enter the time in format hhmm eg 1750 for 5:50 p.m. :  5
# 0 5
# Now showing from :2024-06-25 00:05:00 to present

# %%
#### -*- coding: utf-8 -*-|
import re
alphabets= "([A-Za-z])"
prefixes = "(Mr|St|Mrs|Ms|Dr|www|est|Est|op|Op|approx|mgmt|mgt|Jan|Feb|Mar|Apr|Jun|Jul|Aug|Sept|Oct|Nov|Dec|vs|VS|Vs)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co|vs|est)"
starters = "(Mr|Mrs|Ms|Dr|Prof|Capt|Cpt|Lt|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov|edu|me|in|BO|NS)"
digits = "([0-9])"
multiple_dots = r'\.{2,}'

#function defined for splitting entire email body contents into separate sentences
def split_into_sentences(text: str) -> list[str]:
    """
    Split the text into sentences.
    
    If the text contains substrings "<prd>" or "<stop>", they would lead 
    to incorrect splitting because they are used as markers for splitting.
    :param text: text to be split into sentences
    :type text: str
    :return: list of sentences
    :rtype: list[str]
    """
    text = " " + text + "  "
    text = text.replace("\n",".")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    text = re.sub(digits + "[.]" + digits,"\\1<prd>\\2",text)
    text = re.sub(multiple_dots, lambda match: "<prd>" * len(match.group(0)) + "<stop>", text)
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + alphabets + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + alphabets + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    text = text.replace(".",".<stop>")
    text = text.replace("?","?<stop>")
    text = text.replace("!","!<stop>")
    text = text.replace("<prd>",".")
    sentences = text.split("<stop>")
    sentences = [s.strip() for s in sentences]
    if sentences and not sentences[-1]: sentences = sentences[:-1]
    return sentences

# %%
import transformers
from transformers import PegasusTokenizer, PegasusForConditionalGeneration

# Let's load the model and the tokenizer 
def summa(body_content,sub):

    model_name = "human-centered-summarization/financial-summarization-pegasus"
    tokenizer = PegasusTokenizer.from_pretrained(model_name)
    model = PegasusForConditionalGeneration.from_pretrained(model_name) # If you want to use the Tensorflow model 
    try:
        body_content=body_content[:re.search(r'\+?\(?[1-9][0-9 .\-\(\)]{8,}[0-9]', body_content).start()]
    except:
         pass
    st=''
    if body_content.count(' ')>1500:
        body_content=body_content[:10000]
    
    for i in range(int(len(body_content)/500)):
        input_ids = tokenizer(body_content[500*i:500*i+500], return_tensors="pt").input_ids
        # Generate the output (Here, we use beam search but you can also use any other strategy you like)
        output = model.generate(
            input_ids, 
            max_length=32, 
            num_beams=5, 
            early_stopping=True
        )
        st+=str(tokenizer.decode(output[0], skip_special_tokens=True))
    print(st+'-'*200)
    other_row["summary"]=st
    other_row["Subject"]=sub

# %%
#function for jefferies company wise summarizing
def jefferies(body_content,sub):
    body_content=body_content.replace('\n','.')
    row['Analysts Opinion']=f'\'{sub}\''
    list_of_sentences=split_into_sentences(body_content)
    for n,j in enumerate(list_of_sentences):
        if 'Subject' in j:
            continue
        if j.count('|')==3:
            jparts=j.split('|')
            row["Name"]=jparts[0]+'\nJEF' if jparts[0][:4]!='Ltd.' else ''
            row["Target"]=jparts[2].split(':')[1] if jparts[2].count(':')==1 else jparts[2]
            row["% to TP"]=jparts[3].split(':')[1] if jparts[3].count(':')==1 else jparts[3]
        if '<https://javatar.' in j:
            j=j.replace('<https://javatar.','.')
        list_of_sentences[n]=j.replace('\n',".").replace('\r',"");
        ebitda_words=[' ebitda ',' ebit ',' opm ',' ebitdam ',' vnbm ',' nim ',' nims ',' operating profit ',' margin',' vnbm ']
        revenue_words=[' revenue ',' revpar ',' arr ' ,' sales ',' nii ',' operating income ',' fee income ',' ape ',' vnb ',' volume',' pricing',' realization',' realisation',' orders ','bill','acv','tcv','book to bill','book-to-bill','order book','order backlog']
        pat_words=[' pat ',' apat ',' profit after tax ',' net income ',' roev ',' ev ',' earning',' bv ',' bvps ','book vaule']
        res = any(ele in j.lower() for ele in ebitda_words)
        if 'Exhibit ' in j:
            continue
        if 'we ' in j.lower() or ' our' in j.lower():
            row["Analysts Opinion"]+="\n"+j
        elif res:
            row["EBITDA"]+="\n"+j;
        elif any(ele in j.lower() for ele in revenue_words):
            row["Revenue"]+="\n"+j;
        elif any(ele in j.lower() for ele in pat_words):
            row["PAT"]+="\n"+j;
    if row["Name"]=='':
        summa(body_content,'JEF'+sub)

# %%
#function for citi company wise summarizing
def citi(sub,body_content):
    list_of_sentences=split_into_sentences(body_content)
    body_content=body_content.replace("\u2014", "-")
    flag=0
    if sub[-1]==')':
            flag=1
    else:
        row['Analysts Opinion']=f'\'{sub}\''
        for n,j in enumerate(list_of_sentences):
            end=sub.find('(') if sub.find('(') >0 else 999 
            row['Name']=sub[0:min(22,end)]+'\nCiti'
            ebitda_words=[' ebitda ',' ebit ',' opm ',' ebitdam ',' vnbm ',' nim ',' nims ',' operating profit ',' margin',' vnbm ']
            revenue_words=[' revenue ',' revpar ',' arr ' ,' sales ',' nii ',' operating income ',' fee income ',' ape ',' vnb ',' volume',' pricing',' realization',' realisation',' orders ','bill','acv','tcv','book to bill','book-to-bill','order book','order backlog']
            pat_words=[' pat ',' apat ',' profit after tax ',' net income ',' roev ',' ev ',' earning',' bv ',' bvps ','book vaule']
            if '<tel:+91' in j:
                break
            if 'target ' in j.lower() or ' tp ' in j.lower():
                row["Target"]=j
            link_index=j.find('<https:')
            if link_index !=-1:#checking if there is a link in this sentence
                j=j[0:link_index]+j[j.find('>',link_index):]#in order to remove only the part within <> as that is ussualy a hyperlink
            elif 'we ' in j.lower() or ' our ' in j.lower():
                if j not in row["Analysts Opinion"]:
                    row["Analysts Opinion"]+="\n"+j
            elif any(ele in j.lower() for ele in ebitda_words):
                if j not in row["EBITDA"]:
                    row["EBITDA"]+="\n"+j
            elif any(ele in j.lower() for ele in revenue_words):
                if j not in row["Revenue"]:
                    row["Revenue"]+="\n"+j
            elif any(ele in j.lower() for ele in pat_words):
                if j not in row["PAT"]:
                    row["PAT"]+="\n"+j
    if row["Name"]=='' or flag ==1:
        summa(body_content,'Citi\n'+sub)

# %%
#function for macquarie company wise summarization
def macquire(sub,body_content):
    if sub.count('(') <2:
        if 'desk stratergy' in body_content.lower() or True:
            summa(body_content,"Mac\n"+sub)
        return
    if "flashnote" in sub.lower():
        row['Name']=sub[sub.find('flashnote')+9:sub.find('(') ]+'\nMacquarie'
    else:
        row['Name']=sub[0:sub.find('(')]+'\nMacquarie'
    row['Analysts Opinion']=f'\'{sub}\''
    flag=0
    list_of_sentences=split_into_sentences(body_content)
    for n,j in enumerate(list_of_sentences):
        #print(j+"\n")
        #list_of_sentences[n]=j.replace('\n',".").replace('\r',"");
        ebitda_words=[' ebitda ',' ebit ',' opm ',' ebitdam ',' vnbm ',' nim ',' nims ',' operating profit ',' margin',' vnbm ']
        revenue_words=[' revenue ',' revpar ',' arr ' ,' sales ',' nii ',' operating income ',' fee income ',' ape ',' vnb ',' volume',' pricing',' realization',' realisation',' orders ','bill','acv','tcv','book to bill','book-to-bill','order book','order backlog']
        pat_words=[' pat ',' apat ',' profit after tax ',' net income ',' roev ',' ev ',' earning',' bv ',' bvps ','book vaule']
        if '<tel:+91' in j:
            break
            
        link_index=j.find('<http:')
        if link_index !=-1:#checking if there is a link in this sentence
            j=j[0:link_index]+j[j.find('>',link_index):]
        link_index=j.find('<https:')
        if link_index !=-1:#checking if there is a link in this sentence
            j=j[0:link_index]+j[j.find('>',link_index):]
            
        if ('target' in j.lower() or ' tp ' in j.lower() or 'pt ' in j.lower()) and flag==0 :
            r=n+1;flag=1
            while  any(chr.isdigit() for chr in list_of_sentences[r]) and list_of_sentences[r]!='.':
                r=r+1
            row["Target"]=j+'\n'+list_of_sentences[r]
            print(list_of_sentences[r])
        if 'we ' in j.lower() or 'our' in j.lower():
            if j not in row["Analysts Opinion"]:
                row["Analysts Opinion"]+="\n"+j
        elif any(ele in j.lower() for ele in ebitda_words):
            if j not in row["EBITDA"]:
                row["EBITDA"]+="\n"+j
        elif any(ele in j.lower() for ele in revenue_words):
            if j not in row["Revenue"]:
                row["Revenue"]+="\n"+j
        elif any(ele in j.lower() for ele in pat_words):
            if j not in row["PAT"]:
                row["PAT"]+="\n"+j

# %%
def Investec(sub,body_content):
    body_content=body_content.replace('\n','.')
    list_of_sentences=split_into_sentences(body_content)
    row['Analysts Opinion']=f'\'{sub}\''
    for n,j in enumerate(list_of_sentences):
        if 'Subject' in j:
            continue
        link_index=j.find('<http:')
        if link_index !=-1:#checking if there is a link in this sentence
            j=j[0:link_index]+j[j.find('>',link_index):]
        link_index=j.find('<https:')
        if link_index !=-1:#checking if there is a link in this sentence
            j=j[0:link_index]+j[j.find('>',link_index):]
            
        if j.count('|')==2:
            jparts=j.split('|')
            row["Name"]=list_of_sentences[n-3]+list_of_sentences[n-2]+'\nInvestec'
            row["Target"]=jparts[1].split(':')[1] 
        list_of_sentences[n]=j.replace('\n',".").replace('\r',"");
        ebitda_words=[' ebitda ',' ebit ',' opm ',' ebitdam ',' vnbm ',' nim ',' nims ',' operating profit ',' margin',' vnbm ']
        revenue_words=[' revenue ',' revpar ',' arr ' ,' sales ',' nii ',' operating income ',' fee income ',' ape ',' vnb ',' volume',' pricing',' realization',' realisation',' orders ','bill','acv','tcv','book to bill','book-to-bill','order book','order backlog']
        pat_words=[' pat ',' apat ',' profit after tax ',' net income ',' roev ',' ev ',' earning',' bv ',' bvps ','book vaule']
        res = any(ele in j.lower() for ele in ebitda_words)
        if 'IMPORTANT NOTICE' in j:
            break
        if 'we ' in j.lower() or ' our' in j.lower():
            row["Analysts Opinion"]+="\n"+j
        elif res:
            row["EBITDA"]+="\n"+j;
        elif any(ele in j.lower() for ele in revenue_words):
            row["Revenue"]+="\n"+j;
        elif any(ele in j.lower() for ele in pat_words):
            row["PAT"]+="\n"+j;
    if row["Name"]=='':
        summa(body_content,'Investec\n'+sub)

# %%
def CLSA(sub,body_content):
    body_content=body_content.replace('\n','.')
    list_of_sentences=split_into_sentences(body_content)
    row['Analysts Opinion']=f'\'{sub}\''
    for n,j in enumerate(list_of_sentences):
        
        link_index=j.find('<http:')
        if link_index !=-1:#checking if there is a link in this sentence
            j=j[0:link_index]+j[j.find('>',link_index):]
        link_index=j.find('<https:')
        if link_index !=-1:#checking if there is a link in this sentence
            j=j[0:link_index]+j[j.find('>',link_index):]
            
        if 'India >'in j:
            row['Name']=j[7:-5]
        if 'Subject' in j:
            continue                                                    
        list_of_sentences[n]=j.replace('\n',".").replace('\r',"");
        print(j+'\n')
        ebitda_words=[' ebitda ',' ebit ',' opm ',' ebitdam ',' vnbm ',' nim ',' nims ',' operating profit ',' margin',' vnbm ']
        revenue_words=[' revenue ',' revpar ',' arr ' ,' sales ',' nii ',' operating income ',' fee income ',' ape ',' vnb ',' volume',' pricing',' realization',' realisation',' orders ','bill','acv','tcv','book to bill','book-to-bill','order book','order backlog']
        pat_words=[' pat ',' apat ',' profit after tax ',' net income ',' roev ',' ev ',' earning',' bv ',' bvps ','book vaule']
        res = any(ele in j.lower() for ele in ebitda_words)   
        if 'Click to rate this research' in j:
            break
        if 'target ' in j.lower() or ' tp ' in j.lower():
                row["Target"]=j
        if 'we ' in j.lower() or 'our ' in j.lower():
            row["Analysts Opinion"]+="\n"+j
        elif res:
            row["EBITDA"]+="\n"+j;
        elif any(ele in j.lower() for ele in revenue_words):
            row["Revenue"]+="\n"+j;
        elif any(ele in j.lower() for ele in pat_words):
            row["PAT"]+="\n"+j;
    if row["Name"]=='':
        summa(body_content,'CLSA\n'+sub)

# %%
import win32com.client

outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

inbox = outlook.GetDefaultFolder(6) # "6" refers to the index of a folder - in this case,
                                    # the inbox. You can change that number to reference
                                    # any other folder
emailno=0
rows_list=[]
other_list=[]
messages = inbox.Items.Restrict(f"[SentOn] > '"+todays_date.strftime('%d/%m/%Y %H:%M %p') +"'")
for found in messages:
    #creating a dictionary with all the columns
    row={key: None for key in ['Name','Date', 'Target', '% to TP', 'EBITDA', 'PAT', 'Revenue','Analysts Opinion'] }
    other_row={key:"" for key in ['Subject','Date','summary']}
    body_content=found.body #assigning the body parameter of the email 
    row={key:"" for key in row}
    # for each email matched, read it (output plain/text to console & save HTML and attachments)
    try:
        row["Date"]=str(found.ReceivedTime)[:16]
    except:
        continue
    other_row["Date"]=row["Date"]
    emailno+=1
    sub=found.subject
    #choosing which firms function to move into
    if 'Investec' in body_content:
        Investec(sub,body_content)
    elif "CITI'S TAKE" in body_content:
        citi(sub,body_content)
    elif "jefferies" in body_content: 
        jefferies(body_content,sub) 
    elif "macquarie" in body_content.lower():
        macquire(sub,body_content)
    elif "clsa" in body_content.lower():
        CLSA(sub,body_content)
    else:
        continue;
    rows_list.append(row)
    other_list.append(other_row)
    
print('No. of emails checked:',emailno)
df=pd.DataFrame(rows_list)
other_df=pd.DataFrame(other_list)
#df = df[['Name','Date', 'Target', '% to TP', 'EBITDA', 'PAT', 'Revenue','Opinion']]
try:    
    df = df[df.Name != ""]
    other_df = other_df[other_df.summary != ""]
except:
    pass
# Out:
# .
#
# .
#
# .
#
# .
#
# From: Indrajit Agarwal, CLSA [mailto:indrajit.
#
# .garwal@clsa.com]
#
# .ent: Thursday, June 27, 2024 12:57 PM
#
# To: Ankit Pande <Ankit.
#
# .ande@quant.in>
#
# .
#
# .
#
# .
#
# .  <http://www.clsa.com/ev/AxQMG7ujTRox9czaKojaYVqtmw7rtPuqL5k6JDp2hg>
#
# .
#
# .
#
# .
#
# .ndia > cement >
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .y Indrajit Agarwal | Open PDF >  | Open in clsa.com <http://www.clsa.com/ev/AwgMG_7lmR_W2bgvLYjaMwArJhXKXHacgEK9QYyMmw>  | Open analyst page <http://www.clsa.com/ev/AwgMG_7lmR_W2bgvKsoE0F9izDXaASw9hiUyGoUZxg>
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .ace for the south heats up >
#
# .
#
# Ultratech picks up 23% stake in India Cements valued at US$80/T.
#
# .
#
# .
#
# .
#
# .
#
# Consolidation in the Indian cement sector continues to pick up pace with Adani Group (ACC + Ambuja) and Ultratech being more aggressive.
#
# Over the past six months, smaller companies controlling c.8% of all Indian capacity have been in transactions with these two groups.
#
# In a recent development, Ultratech has acquired 23% of the equity share capital of India Cements (ICL) at Rs267/share, implying a valuation of c.US$80/T.
#
# Given it is a financial investment, UTCEM will not have control over the assets or a board seat, although it gives it a foot in the door.
#
# Inorganic expansion has a much lower adverse impact on the industry demand-supply balance than organic capacity addition.
#
# Moreover, it raises consolidation, providing pricing power and hence augurs well for the industry.
#
# .
#
# .
#
# .
#
# .
#
# *	What has happened: Ultratech has acquired 23% of the equity share capital of India Cements (ICL) at Rs267/share (June 26 close Rs264), implying an outgo of Rs16.6bn (US$200m).
#
# While an open offer is not mandated, we will await further details on this.
#
# .
#
# .
#
# *	Valuation: ICL has a total capacity of 16mt (operating at c.65% utilisation), of which 13.5mt is in the south.
#
# With US$300m debt as of FY24, the deal values ICL at US$80/T of cement capacity.
#
# This compares with a replacement cost of US$90-110/T and recent deals at similar levels.
#
# Given low profitability at ICL, an EV/Ebitda comparison does not make sense.
#
# ICL’s large landbank could facilitate further organic expansion.
#
# .
#
# .
#
# *	Regulatory requirement: Given it is a financial investment, and UTCEM will not have any operational control or board seat, this will not involve competition commission (CCI) approval.
#
# Moreover, given the acquired stake is less than 25%, UTCEM will not need to make an open offer.
#
# However, if UTCEM intends to take its stake up and get control of the company in the future, these provisions would likely kick in.
#
# .
#
# .
#
# *	Implications for the industry: In the past six months, industry consolidation has picked up pace with c.47mt capacity (c.
#
# 8%) being involved in transactions involving the two largest players, Ultratech and Adani Group (Ambuja).
#
# We see further consolidation likely with Vadraj Cement, Saurashtra Cement and Jaiprakash Associates (link .
#
# cms?
#
# from=mdr> ) likely up for grabs as per news stories.
#
# More importantly, this raises consolidation in the South India market meaningfully, which could support price in an otherwise low-utilisation region.
#
# Assuming UTCEM ultimately controls ICL assets, the top five players would control 61% of all-India capacity by FY27 (52% currently), while in the south the figure would rise to 57% (41% currently).
#
# .
#
# .
#
# *	Implications for Ultratech: Given it is a financial investment, UTCEM will not have any operational control; however, it gives UTCEM a foot in the door at ICL.
#
# By FY27, UTCEM will have c.46mt capacity in the south (including Kesoram), implying 20% capacity market share, up from 10% share (c.
#
# 21mt capacity) in FY24.
#
# Assuming ICL also is consolidated at some point in future, this would raise UTCEM’s capacity to 60mt in the south, c.26% share.
#
# Moreover, ICL has been making PAT losses in the recent past, with Ebitda/T of Rs105 in FY24.
#
# Given UTCEM’s history of turning around acquired assets (Jaiprakash Associates and Binani), we could see profitability jump here as well.
#
# Also, UTCEM’s capacity in the south has largely been in Andhra Pradesh and Karnataka (except Tamil Nadu: 2.5mt), while ICL is largely in Tamil Nadu.
#
# .
#
# .
#
# *	CLSA view: Inorganic expansion by incumbents is not as much a concern for the demand-supply balance given the facilities are already operational, although the acquired assets have been operating at low utilisations.
#
# Moreover, with inorganic expansion picking up, we could see organic expansions take a breather, even for announced capacities.
#
# .
#
# .
#
# .
#
# .
#
# .ore> >
#
# .
#
# .
#
# .
#
# .lick to rate this research
#
# .
#
# .
#
# .
#
# .
#
# From: Shreya Shivani, CLSA [mailto:shreya.
#
# .hivani@clsa.com]
#
# .ent: Friday, June 28, 2024 8:37 AM
#
# To: Ankit Pande <Ankit.
#
# .ande@quant.in>
#
# .
#
# .
#
# .
#
# .  <http://www.clsa.com/ev/AxEMHCziyK_H3L0gIojaMwAPSBhcifjB8MFLrhZ8QQ>
#
# .
#
# .
#
# .
#
# .ndia > Star Health >
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Email Shreya Shivani <mailto:shreya.
#
# shivani@clsa.com?
#
# .ubject=CLSA:%20Star%20Health%20(STARHEAL%20IN):%20Takeaways%20from%20analyst%20meeting>  | Open PDF >  | Open in clsa.com <http://www.clsa.com/ev/AxUMHFuTPT7D_czaKoiIb5uOULGgw95X0y7os6IRyQ>  | Open analyst page <http://www.clsa.com/ev/AwsMHAuySB8-_cUl5tjoMzY-EkTDviA5peEcVBVxeA>  | Open company page on clsa.com <http://www.clsa.com/ev/AwgMHP7lmR_W2bgvKv80Lgb7nTpshyrw1ZExZF_kEg>
#
# .
#
# .eplies to this email are not monitored, please email the analyst directly using the email link above
#
# .
#
# .
#
# .
#
# .akeaways from analyst meeting >
#
# .
#
# .xpect ROE of 18-19% in FY26-27; maintain BUY >
#
# .
#
# .
#
# .
#
# Star Health’s (Star) management laid out long-term guidance in its analyst meeting.
#
# It aims to double the company’s premiums over the next four years and triple net profit, supported by improvement in COR and new accounting method.
#
# Overall, Star believes it can deliver a 19-20% ROE over the medium term.
#
# For FY25, it is targeting a 100bp improvement in COR.
#
# We expect growth momentum to pick up from July 2024 while we build in 19% growth for FY25.
#
# We adjust our estimates as per management targets, and lower FY25/26CL net profit 9%/3%.
#
# For expected ROE of 18-19%, a FY26CL PE of 21.5x is inexpensive, in our view.
#
# Maintain BUY, with an unchanged TP of Rs700.
#
# .
#
# .
#
# .
#
# .
#
# .iming for 3x increase in net profit by FY28
#
# .
#
# Star has laid out strong guidance for FY28.
#
# Driven by broad-based growth across channels, it expects to double its gross written premium to Rs300bn in the next four years; this translates to an 18.5% Cagr.
#
# Its market share in retail health stood at 33% in FY24 and it aims to take it to 35% by FY28.
#
# This, along with improvement in combined ratio and new accounting method, should lead to 3x growth in net profit as per management; aiming for Rs25bn net profit in FY28.
#
# .
#
# .
#
# .
#
# .
#
# .argets to reduce FY25 COR by 100bp
#
# .
#
# Management aims to reduce the elevated combined ratio of FY24 (of 96.7%) by 100bp in FY25.
#
# It believes it can deliver a 50bp improvement in loss ratio and a 50bp improvement in expense ratio.
#
# On the profitability front, Star believes it can deliver 19-20% ROE (on IFRS basis) with a 95% combined ratio.
#
# While it did not share guidance, it is hoping to maintain a 65% loss ratio over the medium term.
#
# .
#
# .
#
# .
#
# .
#
# .ell placed in an evolving industry
#
# .
#
# Star believes that composite licence and long-term health policies provide it with many opportunities, such as return of premium kind of health insurance products.
#
# Separately, the government recently launched free health cover for citizens over the age of 70 (link > ).
#
# While this puts the total addressable market at risk, Star still sees an opportunity here as sum assured may not be adequate under such schemes.
#
# .
#
# .
#
# .
#
# .
#
# .oss ratio trend key to watch out for; maintain BUY
#
# .
#
# Star had actively backed away from certain geographies last year, resulting in slower growth trends in 2Q/3Q24.
#
# We expect growth momentum to pick up from July 2024 and build 19% growth for FY25.
#
# We also raise our FY27 net profit forecast to reflect IFRS adjusted profits.
#
# For a 19% ROE profile, Star currently trades at a 21.5x PE which we consider inexpensive.
#
# A recovery in loss ratios and growth pickup will be key triggers, in our view.
#
# Maintain BUY with an unchanged TP of Rs700.
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .ore> >
#
# .
#
# .
#
# .
#
# .lick to rate this research
#
# .
#
# .
#
# .
#
# .
#
# From: Deepti Chaturvedi, CLSA [mailto:deepti.
#
# .haturvedi@clsa.com]
#
# .ent: Friday, June 28, 2024 12:41 AM
#
# To: Ankit Pande <Ankit.
#
# .ande@quant.in>
#
# .
#
# .
#
# .
#
# .  <https://www.clsa.com/member>
#
# .
#
# .
#
# .
#
# .ndia > Telecoms >
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .y Deepti Chaturvedi | Open PDF >  | Open in clsa.com <https://www.clsa.com/ev/AQ8MHH-vSFeapcTaKojbn91ZZkT0NAt4WKeY>  | Open analyst page <https://www.clsa.com/ev/AQ4MHKBrP21tUw_SKojaMqzSTDhvSgIWE02A>
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .ariff hike by Reliance Jio >
#
# .
#
# .ike in prepaid & post-paid tariffs by 13%-25%; JioPhone plans unchanged >
#
# .
#
# .
#
# .
#
# Reliance Jio (RJio) hiked prepaid tariffs by 13%-25%, effective 3 July 2024.
#
# RJio even lifted the entry post-paid plan 17% to Rs349.
#
# Also, RJio changed the threshold for subscribers to avail 5G services from 1.5GB/day to 2GB/day implying minimum spending of Rs349—an increase of 46%.
#
# However, RJio left JioBharat and JioPhone (bundled 4G handsets) user tariffs unchanged.
#
# RJio's new 28-days 1GB daily prepaid plan still offers 6%-7% lower rates to Bharti Airtel (Bharti) and Vodafone Idea (VIdea), but in the popular 56-day plans offering 1.5/2GB daily, RJio’s tariffs are now at 15%-21% premiums to Bharti and VIdea.
#
# Historically, Bharti and VIdea tariffs have been at c.20%-25% premiums to RJio.
#
# The key will be whether Bharti and VIdea lift tariffs over the coming days or follow with a lag.
#
# Our RJio forecasts factor in 6%-13% increases in FY25/26CL Arpus to Rs206/Rs218 from Rs182.
#
# We forecast RJio’s subscribers to be at 527m by FY26CL from 482m in 4QFY24.
#
# .
#
# .
#
# .
#
# .
#
# *	India mobile sector leader, RJio, lifted prepaid tariffs 13%-25%, which will be effective on 3 July 2024.
#
# .
#
# .
#
# *	In 28=day valid plans of 1-1.5GB daily usage, RJio’s tariffs were lifted 19%-25% from Rs209-Rs239 to Rs249-Rs299.
#
# .
#
# .
#
# *	Notable, is that RJio changed the threshold for subscribers to avail unlimited 5G services from 1.5GB/day to 2GB/day, which implies users will need to pay a minimum Rs349 to avail 5G services (Rs239 earlier), an increase of 46%.
#
# .
#
# .
#
# *	RJio also lifted post-paid tariffs with the entry plan increased 17% to Rs349.
#
# .
#
# .
#
# *	RJio has left the JioBharat and JioPhone (bundled 4G handsets) user tariffs unchanged at Rs123 for 28-days.
#
# .
#
# .
#
# *	Comparing RJio's new 28-day prepaid plan offering 1GB daily at Rs249 to Bharti and VIdea shows RJio still offers 6%-7% lower rates.
#
# .
#
# .
#
# *	However, RJio's new 28-day prepaid plan of Rs299, which offers 1.5GB of daily usage, the tariff is now comparable to offers from Bharti and Videa.
#
# .
#
# .
#
# *	While in the popular longer duration 56-day plans offering 1.5/2GB daily, RJio’s tariffs at Rs579/Rs629 are now at 15%-21% premiums to Bharti and VIdea.
#
# .
#
# .
#
# .	Even in the other popular longer duration 84-day plans offering 1.5/2GB daily, RJio’s new tariffs at Rs799/Rs859 are at 2%-11% premiums to Bharti and VIdea
#
# .
#
# *	Even as RJio’s new tariff plans will compel higher spending by its 4G and 5G subscribers and boost its Arpu meaningfully despite risk of down-trading and subscriber churn, the key will be whether Bharti and VIdea hike tariffs over coming days or follow with a lag.
#
# .
#
# .
#
# *	Historically Bharti’s and VIdea’s tariffs have been at c.20%-25% premiums to RJio.
#
# .
#
# .
#
# *	Besides, a key drag on RJio’s Arpu remains JioPhone and JioBharat users where the Arpu is significantly lower versus smartphones as bundled 4G feature phone users can still get 336-day entry service for Rs895/Rs1,234 (Rs80/Rs110 month).
#
# .
#
# .
#
# *	Our RJio forecasts factor in a 6%-13% increase in FY25/26CL Arpu to Rs206/Rs218 from Rs182 in 4QFY24.
#
# We remain positive on RJio and also forecast 527m subscribers by FY26CL from 482m in 4QFY24.
#
# .
#
# .
#
# .
#
# .
#
# .ore> >
#
# .
#
# .
#
# .
#
# .lick to rate this research
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at human-centered-summarization/financial-summarization-pegasus and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Korea’s Kospi 200 has reinforced its recent breakout.Japan’s Topix looks set to break out of consolidation pattern. Indonesia’s LQ45 provides a bottom-fishing opportunityChina momentum continues to work its way higher.Daily momentum indicator has confirmed recent highs.Nikkei and Topix finally clear hurdle below 38,724 area.Japan Post seen as a buy candidateKorea’s main share index, the Kospi, is trading lower.Shares of HDFC Bank seen breaking out of trading range since 2021S&P500 continues to work its way higher following the breakout from the March-April trading range.Daily momentum indicator is still confirming recent highsJuly has been the best performing month of the year with an average return of 2.27%.Daily momentum indicator has confirmed last week’s all-time highs.Support seen at 19,393, 18,700 and 17,200 levelsBreak of 38,724 opens door for move back to March highs at 40,472.The current range is seen as a digestion phase of the impressive gains seen in 1Q24. Breaking above 40,472-41,087 would support an upsideJapan Post Holding presented as a buy candidate. At the stock level, Japan Post Holding is presented as a buy candidate.Bitcoin stays within consolidation range of 2021-2023 trading range.Shares of REA Group and Macquarie have recently broken out of trading ranges.--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# No. of emails checked: 6

# %%
pd.set_option("max_colwidth", None)
cwd = os.getcwd()
path = cwd + '//'+f"Earnings Reports Summary {str(day)}-{str(month)}-{str(year)}"+".xlsx"
print(cwd)
df=df.drop_duplicates(subset=["Name"])
writer = pd.ExcelWriter(path) 
# Get the xlsxwriter workbook 
workbook  = writer.book
# Add a format.
text_format = workbook.add_format({'text_wrap' : True})
df.to_excel(writer, sheet_name='Earnings Report', index=False,freeze_panes=(1, 1) )
writer.sheets['Earnings Report'].set_column(0,0 ,20,text_format)
writer.sheets['Earnings Report'].set_column(1,1 , 9.7,text_format)
writer.sheets['Earnings Report'].set_column(2,2 ,8,text_format)
writer.sheets['Earnings Report'].set_column(3,3 ,3.5,text_format)
writer.sheets['Earnings Report'].set_column(4,4 ,55,text_format)
writer.sheets['Earnings Report'].set_column(5,5 ,50,text_format)
writer.sheets['Earnings Report'].set_column(6,6 ,55,text_format)
writer.sheets['Earnings Report'].set_column(7,7,60,text_format)
writer.close()
# Out:
# C:\Users\research.intern1\Desktop

# %%
cwd = os.getcwd()
path = cwd + '//'+f"other {str(day)}-{str(month)}-{str(year)}"+".xlsx"
print(cwd)
other_df=other_df.drop_duplicates()
other_df.to_excel(path,sheet_name='Other Reports',index=False,freeze_panes=(1, 1))
# Out:
# C:\Users\research.intern1\Desktop
